# %%
import numpy as np
from osgeo import gdal

# %%
def remove_outliers(input_file, output_file):  # 取96%
    # 打开栅格文件
    dataset = gdal.Open(input_file)
    if dataset is None:
        print("无法打开文件: ", input_file)
        return

    # 读取栅格数据
    band = dataset.GetRasterBand(1)
    array = band.ReadAsArray()
    
    # 获取不是NaN的值
    non_nan_values = array[~np.isnan(array)]
    
    # 计算去除前后2%后的百分位数
    non_nan_values = np.sort(non_nan_values)
    num_values = len(non_nan_values)
    low_percentile_index = int(num_values * 0.02)
    high_percentile_index = int(num_values * 0.98)
    low_percentile = non_nan_values[low_percentile_index]
    high_percentile = non_nan_values[high_percentile_index]
    print(input_file, '\n', low_percentile, high_percentile)
    
    
    # 将超出百分位数范围的值设为NaN
    array[array < low_percentile] = np.nan
    array[array > high_percentile] = np.nan

    # 写入处理后的数据到输出文件
    driver = gdal.GetDriverByName('GTiff')
    output_dataset = driver.Create(output_file, dataset.RasterXSize, dataset.RasterYSize, 1, band.DataType)
    output_dataset.SetProjection(dataset.GetProjection())
    output_dataset.SetGeoTransform(dataset.GetGeoTransform())
    output_band = output_dataset.GetRasterBand(1)
    output_band.WriteArray(array)

    # 关闭数据集
    dataset = None
    output_dataset = None

    print("处理完成")

# %%
def calculate_average(input_files, output_file):   # 计算均值
    num_files = len(input_files) 
    dataset = gdal.Open(input_files[0])
    if dataset is None:
        print("无法打开文件欸: ", input_files[0])
        return

    # 读取栅格数据
    band = dataset.GetRasterBand(1)
    array_sum = band.ReadAsArray()

    # 统计有效值的数量
    valid_count = np.ones(array_sum.shape)

    for i in range(1, num_files):
        dataset = gdal.Open(input_files[i])
        if dataset is None:
            print("无法打开文件: ", input_files[i])
            continue

        band = dataset.GetRasterBand(1)
        array = band.ReadAsArray()

        # 更新数组总和和有效值的数量
        valid_mask = np.logical_not(np.isnan(array))
        array_sum[valid_mask] += array[valid_mask]
        valid_count += valid_mask

    # 计算平均值
    average_array = np.where(valid_count > 0, array_sum / valid_count, np.nan)

    # 写入平均值到输出文件
    driver = gdal.GetDriverByName('GTiff')
    output_dataset = driver.Create(output_file, dataset.RasterXSize, dataset.RasterYSize, 1, band.DataType)
    #print('1')
    #print(dataset.GetProjection())
    output_dataset.SetProjection(dataset.GetProjection())
    output_dataset.SetGeoTransform(dataset.GetGeoTransform())
    output_band = output_dataset.GetRasterBand(1)
    output_band.WriteArray(average_array)

    # 关闭数据集
    dataset = None
    output_dataset = None

    print("平均值计算完成")

# %%
# ‘NoneType‘ object has no attribute ‘GetGeoTransform是路径错了
index_names = [
    'apar','EVI2_type_A','EVI2_type_B','EVI2_type_C','fesc_type_A','fesc_type_B','fesc_type_C',
    'FPAR','GPP_CEDAR','GPP_fluxcom','kNDVI_type_B','kNDVI_type_C','LAI','LUE_CEDAR','LUE_fluxcom','NDVI_type_A',
    'NDVI_type_B','NDVI_type_C','new_kNDVI_type_C','NIRv_type_A','NIRv_type_B','NIRv_type_C','NIRvP','NIRvR',
    'par','sif','SIF_yield_P','SIF_yield_R','sifapar'
]
region = 'cornbelt'
if __name__ == "__main__":
    list_90 = []
    k = 18
    while k <= 20:
        print(k)
        for i in index_names: 
            input_file =  r"C:\Users\levi\cartopy\5.6data\{}\\{}_20{}_{}.tif".format(region,i,k,region)  # 输入栅格文件名
            output_file = r"C:\Users\levi\cartopy\5.6data\ninety\\{}\\{}_20{}_{}_90.tif".format(region,i,k,region)            
            print(input_file)
            list_90.append(output_file)
            remove_outliers(input_file, output_file)
        k += 1
print(list_90)
# Out:
# 18
# C:\Users\levi\cartopy\5.6data\cornbelt\\apar_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\apar_2018_cornbelt.tif
#  952.09314 1406.3774
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_A_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_A_2018_cornbelt.tif
#  0.44590166 0.717807
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_B_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_B_2018_cornbelt.tif
#  0.43611085 0.7186238
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_C_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_C_2018_cornbelt.tif
#  0.43780652 0.7113629
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_A_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_A_2018_cornbelt.tif
#  0.36535874009132385 0.6024211049079895
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_B_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_B_2018_cornbelt.tif
#  0.3567020297050476 0.600542426109314
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_C_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_C_2018_cornbelt.tif
#  0.35322973132133484 0.5888311862945557
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\FPAR_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\FPAR_2018_cornbelt.tif
#  0.56612897 0.79903245
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\GPP_CEDAR_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\GPP_CEDAR_2018_cornbelt.tif
#  71.65537 125.29523
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\GPP_fluxcom_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\GPP_fluxcom_2018_cornbelt.tif
#  65.926956 142.9949
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\kNDVI_type_B_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\kNDVI_type_B_2018_cornbelt.tif
#  0.40874574 0.6499996
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\kNDVI_type_C_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\kNDVI_type_C_2018_cornbelt.tif
#  0.41739047 0.6528142
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\LAI_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\LAI_2018_cornbelt.tif
#  1.53871 3.37742
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\LUE_CEDAR_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\LUE_CEDAR_2018_cornbelt.tif
#  0.06527798 0.11662411
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\LUE_fluxcom_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\LUE_fluxcom_2018_cornbelt.tif
#  0.058986124 0.12994789
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NDVI_type_A_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NDVI_type_A_2018_cornbelt.tif
#  0.65809494 0.8818681
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NDVI_type_B_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NDVI_type_B_2018_cornbelt.tif
#  0.6572152 0.88093233
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NDVI_type_C_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NDVI_type_C_2018_cornbelt.tif
#  0.66109616 0.8836052
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\new_kNDVI_type_C_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\new_kNDVI_type_C_2018_cornbelt.tif
#  0.41739047 0.6528142
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_A_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_A_2018_cornbelt.tif
#  0.22517453 0.4192153
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_B_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_B_2018_cornbelt.tif
#  0.2191803 0.4195375
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_C_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_C_2018_cornbelt.tif
#  0.21772604 0.41242895
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRvP_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRvP_2018_cornbelt.tif
#  393.1498 726.176
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRvR_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRvR_2018_cornbelt.tif
#  299.98245 546.49347
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\par_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\par_2018_cornbelt.tif
#  1511.6615 1851.7997
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\sif_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\sif_2018_cornbelt.tif
#  0.46694127 0.94469565
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\SIF_yield_P_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\SIF_yield_P_2018_cornbelt.tif
#  0.003333872 0.0055738953
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\SIF_yield_R_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\SIF_yield_R_2018_cornbelt.tif
#  0.0041897236 0.005844295
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\sifapar_2018_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\sifapar_2018_cornbelt.tif
#  0.00042370043 0.00083953416
# 处理完成
# 19
# C:\Users\levi\cartopy\5.6data\cornbelt\\apar_2019_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\apar_2019_cornbelt.tif
#  957.91437 1579.3796
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_A_2019_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_A_2019_cornbelt.tif
#  0.4180164 0.73064524
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_B_2019_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_B_2019_cornbelt.tif
#  0.40726784 0.73545283
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_C_2019_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\EVI2_type_C_2019_cornbelt.tif
#  0.40570292 0.730837
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_A_2019_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_A_2019_cornbelt.tif
#  0.3221093714237213 0.5468038320541382
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_B_2019_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_B_2019_cornbelt.tif
#  0.317898154258728 0.5596063733100891
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_C_2019_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\fesc_type_C_2019_cornbelt.tif
#  0.3159264326095581 0.5500050187110901
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\
2020_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\new_kNDVI_type_C_2020_cornbelt.tif
#  0.36154494 0.65332013
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_A_2020_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_A_2020_cornbelt.tif
#  0.205083 0.3997886
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_B_2020_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_B_2020_cornbelt.tif
#  0.20112573 0.4082177
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_C_2020_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRv_type_C_2020_cornbelt.tif
#  0.20035164 0.40339506
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRvP_2020_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRvP_2020_cornbelt.tif
#  378.1522 733.309
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRvR_2020_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\NIRvR_2020_cornbelt.tif
#  273.30704 472.6857
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\par_2020_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\par_2020_cornbelt.tif
#  1565.0748 1945.7406
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\sif_2020_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\sif_2020_cornbelt.tif
#  0.43101427 0.8891352
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\SIF_yield_P_2020_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\SIF_yield_P_2020_cornbelt.tif
#  0.0031409217 0.006026076
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\SIF_yield_R_2020_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\SIF_yield_R_2020_cornbelt.tif
#  0.0044474 0.006621738
# 处理完成
# C:\Users\levi\cartopy\5.6data\cornbelt\\sifapar_2020_cornbelt.tif
# C:\Users\levi\cartopy\5.6data\cornbelt\\sifapar_2020_cornbelt.tif
#  0.00039910714 0.00065304735
# 处理完成
# ['C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\apar_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\EVI2_type_A_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\EVI2_type_B_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\EVI2_type_C_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\fesc_type_A_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\fesc_type_B_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\fesc_type_C_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\FPAR_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\GPP_CEDAR_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\GPP_fluxcom_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\kNDVI_type_B_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\kNDVI_type_C_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\LAI_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\LUE_CEDAR_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\LUE_fluxcom_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\NDVI_type_A_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\NDVI_type_B_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\NDVI_type_C_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\new_kNDVI_type_C_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\NIRv_type_A_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\NIRv_type_B_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\NIRv_type_C_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\NIRvP_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\NIRvR_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\par_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\sif_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\SIF_yield_P_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\SIF_yield_R_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\sifapar_2018_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\apar_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\EVI2_type_A_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\EVI2_type_B_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\EVI2_type_C_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\fesc_type_A_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\fesc_type_B_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\fesc_type_C_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\FPAR_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\GPP_CEDAR_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\GPP_fluxcom_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\kNDVI_type_B_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\kNDVI_type_C_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\LAI_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\LUE_CEDAR_2019_cornbelt_90.tif', 'C:\\Users\\levi\\cartopy\\5.6data\\ninety\\\\cornbelt\\\\LUE_fluxcom_2019_ ...

# %%
for i in index_names: 
    input_files = []
    for j in range(2018,2021):
        #print(i,j)
        file_name = r"C:\Users\levi\cartopy\5.6data\ninety\\{}\\{}_{}_{}_90.tif".format(region,i,j,region)
        #print(file_name)
        input_files.append(file_name)
    # print(input_files)
    output_file = r"C:\Users\levi\cartopy\5.6data\averg\\avg_{}_{}.tif".format(i,region)  # 输出栅格文件名
    print(output_file)
    calculate_average(input_files, output_file)
# Out:
# C:\Users\levi\cartopy\5.6data\averg\\avg_apar_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_EVI2_type_A_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_EVI2_type_B_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_EVI2_type_C_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_fesc_type_A_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_fesc_type_B_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_fesc_type_C_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_FPAR_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_GPP_CEDAR_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_GPP_fluxcom_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_kNDVI_type_B_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_kNDVI_type_C_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_LAI_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_LUE_CEDAR_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_LUE_fluxcom_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_NDVI_type_A_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_NDVI_type_B_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_NDVI_type_C_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_new_kNDVI_type_C_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_NIRv_type_A_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_NIRv_type_B_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_NIRv_type_C_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_NIRvP_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_NIRvR_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_par_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_sif_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_SIF_yield_P_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_SIF_yield_R_cornbelt.tif
# 平均值计算完成
# C:\Users\levi\cartopy\5.6data\averg\\avg_sifapar_cornbelt.tif
# 平均值计算完成
